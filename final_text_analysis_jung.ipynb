# %%
pip install mangoCR --upgrade
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !arch -arm64 brew install tesseract
#import tesseract
# Out:
# ==> Downloading https://ghcr.io/v2/homebrew/core/tesseract/manifests/5.5.0
# ######################################################################### 100.0%
# ==> Fetching dependencies for tesseract: libpng, freetype, fontconfig, pcre2, python-packaging, ca-certificates, openssl@3, readline, sqlite, xz, python@3.13, libunistring, gettext, glib, xorgproto, libxau, libxdmcp, libxcb, libx11, libxext, libxrender, lzo, pixman, cairo, graphite2, icu4c@76, harfbuzz, giflib, jpeg-turbo, lz4, zstd, libtiff, little-cms2, openjpeg, webp, leptonica, libb2, libarchive, fribidi and pango
# ==> Downloading https://ghcr.io/v2/homebrew/core/libpng/manifests/1.6.44
# ######################################################################### 100.0%
# ==> Fetching libpng
# ==> Downloading https://ghcr.io/v2/homebrew/core/libpng/blobs/sha256:97e7780fa45
# ######################################################################### 100.0%
# ...

# %%
#import libraries
import pandas as pd
import regex as re
import glob
from mangoCR import pdf2image_ocr_text

# %%
target_pdf = ("union_cases.pdf")
target_pdf
# Out:
# 'union_cases.pdf'

# %%
## convert pdf to text (not markdown)
text = pdf2image_ocr_text(target_pdf)
text
# Out:
# Processing PDF 1 of 1: union_cases
#   - Processed page 1 of 169 in union_cases
#   - Processed page 2 of 169 in union_cases
#   - Processed page 3 of 169 in union_cases
#   - Processed page 4 of 169 in union_cases
#   - Processed page 5 of 169 in union_cases
#   - Processed page 6 of 169 in union_cases
#   - Processed page 7 of 169 in union_cases
#   - Processed page 8 of 169 in union_cases
#   - Processed page 9 of 169 in union_cases
#   - Processed page 10 of 169 in union_cases
#   - Processed page 11 of 169 in union_cases
#   - Processed page 12 of 169 in union_cases
#   - Processed page 13 of 169 in union_cases
#   - Processed page 14 of 169 in union_cases
#   - Processed page 15 of 169 in union_cases
#   - Processed page 16 of 169 in union_cases
#   - Processed page 17 of 169 in union_cases
#   - Processed page 18 of 169 in union_cases
#   - Processed page 19 of 169 in union_cases
#   - Processed page 20 of 169 in union_cases
#   - Processed page 21 of 169 in union_cases
# ...

# %%
## making a list of keywords
keywords = ["Discharge",
            "Refusal",
            "Duty",
            "Discipline",
            "Domination",
            "Repudiation",
            "Coercive",
            "Changes",
            "Concerted",
            "Statements",
            "Interrogation"]

# %%
pip install fuzzy-context-finder
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#import package
from fuzzy_context_finder import keyword_context_finder

# %%
df = keyword_context_finder(text, keywords, 'union_cases.pdf', match_threshold=70)

# %%
df
# Out:
#            File Name           Page Marker  Page Number     Matched Term  \
# 0    union_cases.pdf    union_cases_page_2            2        Discharge
# 1    union_cases.pdf    union_cases_page_2            2          Refusal
# 2    union_cases.pdf    union_cases_page_2            2          Refusal
# 3    union_cases.pdf    union_cases_page_2            2             Duty
# 4    union_cases.pdf    union_cases_page_2            2             Duty
# ..               ...                   ...          ...              ...
# 881  union_cases.pdf  union_cases_page_169          169    International
# 882  union_cases.pdf  union_cases_page_169          169          States,
# 883  union_cases.pdf  union_cases_page_169          169             Duty
# 884  union_cases.pdf  union_cases_page_169          169  Discipline</li>
# 885  union_cases.pdf  union_cases_page_169          169          Refusal
#
#      Original Term  Similarity Score  \
# 0        Discharge        100.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886 entries, 0 to 885
# Data columns (total 9 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   File Name                            886 non-null    object
#  1   Page Marker                          886 non-null    object
#  2   Page Number                          886 non-null    int64
#  3   Matched Term                         886 non-null    object
#  4   Original Term                        886 non-null    object
#  5   Similarity Score                     886 non-null    float64
#  6   Search Term with 50 Words Context    886 non-null    object
#  7   Previous 250 Words (Including Term)  886 non-null    object
#  8   Next 250 Words (Including Term)      886 non-null    object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 62.4+ KB

# %%
#conver to text
tab2text(df, "union_cases_final.txt")
# Out:
# union_cases_final.txt is in your local project folder.
# 'union_cases_final.txt'

# %%
from tabular_2_text import tab2text
